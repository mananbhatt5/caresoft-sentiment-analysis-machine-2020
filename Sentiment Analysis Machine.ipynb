# %%
from textblob import TextBlob
from urllib.request import urlopen as uReq
import math

def createReviewList(url):
    client = uReq(url)
    reviewList = []
    reviewList.append("I thought this hotel was very nice, and reasonably priced for such an upscale atmosphere, It was incredibly clean, and all the staff were enforcing masks which I really appreciated. The hotel is in a very good location near train station and a parking garage. There is a nice bagel place steps outside the main door where you can grab coffee and a quick bite in the morning. The best thing is probably the view of Manhattan. It’s relaxing to sit on a bench and just enjoy the view of the boats and the skyline.")
    reviewList.append("Found hair on the floor from previous guest, extrement on toilet seat from previous guest, coffee machine broken, cord to curtains broken and air conditioner broke twice during a 11 night stay. Room felt dirty, bed was worn and had a physical dip in the mattress!! On the first night, after a 9 hour flight, reception did not advice of an event, the music was so loud the walls were vibrating in my room. After I unpacked they said I could move rooms but it would have taken me another hour or so to repack and wish they advise me sooner... my company use this hotel for all their staff and we are now seriously reconsidering for the future!!!")
    reviewList.append("The facility and the staff at the Hyatt Regency were wonderful. The rooms were clean and comfortable and it is very close to the Path and the Harbor, in case you want to go to NYC! I recommend staying there!")
    reviewList.append("Front desk assured me four times that breakfast was included on my gift certificate and I was billed $69 only after I reached home. I spoke to front desk when I reserved, when I registered, when I went to breakfast and after breakfast. Very disappointed.")
    reviewList.append("I absolutely LOVE this property and will stay here every opportunity I get when I want to travel to NYC. I do want to make you aware that the people who handle the reservations do not provide the same high level of customer service that the Hotel staff does. Is this an outsourced area of service? The difference in customer service is staggering. When I booked my reservation back in January I was connected to a reservation specialist who was flat and apathetic. She invited me to become a World of Hyatt member, but could not effectively explain the benefits. However, I still accepted the offer. Later, I needed to make a change to my reservation due to unforeseen circumstances (I needed to move my check-out date up by one day) and I was informed by another reservation specialist that the price for one night instead of two had more than doubled! I asked for an explanation and the agent could not provide one other than to repeat that the rate had changed. She was very flat and apathetic as well and she did not seem to care about my predicament. It seemed ridiculous to pay more for one night then I was originally going to pay for two and since the agent was not trying to help me understand, I reluctantly decided to cancel altogether. This was a GREAT DISAPPOINTMENT to me as I was so looking forward to my stay. My sister saw how upset I was and decided to call back. She spoke with a manager at the actual property. Her name was Myra and she was VERY HELPFUL and SYMPATHETIC!!! She apologized, rebooked my stay and upgraded us to a room with AN AMAZING northeast panoramic view! It was breathtaking! I was BEYOND GRATEFUL and COMPLETELY BLOWN AWAY!!! This is the type of service that I have come to enjoy from the staff at Hyatt Regency Jersey City property!!! I LOVE the way you treat me!!! If the folks who handle registrations are not able to live up to the property’s high-lever customer service standard, I would urge you to coach them ASAP as it can potentially harm the impeccable reputation of the property.")
    reviewList.append("The rooms are in serious need of an upgrade. One of the only two exercise bikes in the gym was broken. And \"room service\" is served in a paper bag with paper plates and plastic silverware. What a joke!")
    reviewList.append("Though we didn’t need much assistance, the staff was very attentive and professional. The room was clean and spacious enough for our needs. The views, at least in our room, were wonderful and if you were planning on visiting downtown Manhattan your proximity to mass transit is just outside the door.")
    reviewList.append("Rooms are tired. Dark, poorly lit. Especially the bathroom. The mirror is a MILE away! Not designed by a woman. Impossible to tweeze an eyebrow or apply makeup, between the dim lighting and the too deep counter. Storing toiletries on the dark shelves, deep under the dark sink is . . . one of the worst design flaws I've experienced in a hotel. It's like they're trying to make life difficult. There's a large piece of furniture (bench? luggage rack?) crowding the doorway of the room, it's so filhy I hesitate to touch it, and, again - it blocks access to the floor length mirror behind it. It's a theme! BUT THE WORST THING IS: No restaurant! Although the website promotes \"The Vu\" restaurant, it's closed for dinner, and has been for months. Staff told us it's more profitable for the hotel to use the space for private group dining. So you can SEE other people dining in the restaurant and enjoying the magnificent view, but that's just to tantalize/irritate you!! YOU aren't allowed!")
    reviewList.append("Pathetic room services, rather no service as such apart from normal room cleaning, below average room facilities, not much to chose in the breakfast menu, Evan this is provided on chargeable basis, cannot consider this hotel under star category, very High cost, can't even expect value for money here, too expensive without any value, Location is the only advantage, near to path station and harbour point, hence hotel seems to don't care about the rest.")
    reviewList.append("Wonderful Hotel- We Love this Place- Top Notch Service, Clean well maintained and WHAT A BEAUTIFUL VIEW! Comfortable room with Dreamy Bedding! Well located , walked to the Ferry 10 minute and fun ride to NYC.")
    reviewList.append("Room was dirty and dusty, hairs allover the blanket, housekeeping never showed up, had to go to the public restroom to get my own toilet paper and tissues as a call and visit to the front desk did not work. Was promised a manager would contact me but that never happened.")
    reviewList.append("The view of NYC skyline was excellent and the proximity , connectivity to NYC through path and ferry was amazing. The staff at Hyatt Regency were prompt and responsive . We requested for some amenities at our room and it was immediately made available within couple of minutes. The breakfast was pretty good and had great service. Highly recommend this stay for excellent view of NYC city.")
    reviewList.append("Well started off ok great view beds are so uncomfortable bathroom floor not cleaned in whole stay I was there only dusted and carpet cleaned wen I complained. Money stole from side cabinet where I left with path ticket hotel finally embursed me!!! My fathers dressing gown which cost a lot of money was stolen fro his room he’s Christmas pressie from me!!!!! Breakfast same every day scrambled eggs taste off powered....told a price in total on fone then decided it was a lot more this hotel used to be nice the only thing nice about this hotel is the views, also my dad cut his leg in room ,blood on sheets overnight the cleaner did not change sheets how disgusting an un hygienic only changed once I reported they were bloodied after 2-3 days far too expensive for wat this hotel is desperately needs refurbish wish I stayed at the new Hyatt house or Westin.")
    
    return reviewList
def getSentiment(review):
    scoredReview = TextBlob(review)
    sentScore = (scoredReview.sentiment.polarity) * 100
    return sentScore

def getMagnitude(contributions, votes):
    magnitude = 1
    if contributions >= 6:
        magnitude *= math.log(contributions, 6)
    if votes >= 4:
        magnitude *= math.log(votes, 4)
    
    return magnitude

def getOutput(review, sentScore, magnitude):
    print("Review: " + review + "\n")
    print("The sentiment score is: " + str(sentScore))
    print("The magnitude is: " + str(magnitude))
    print("\n-------------------------------------------------------------------------------------------------------------------------")
    
def analyzeReviews():
    reviewList = createReviewList("https://www.tripadvisor.com/Hotel_Review-g46531-d246778-Reviews-Hyatt_Regency_Jersey_City-Jersey_City_New_Jersey.html")
    idx = 0
    contList = [24, 1, 1, 36, 12, 1, 1, 17, 1, 1, 5, 10, 78, 10, 9, 56, 3, 2, 145, 4]
    votList = [50, 1, 0, 10, 1, 3, 0, 38, 0, 4, 0, 4, 43, 11, 0, 32, 3, 1, 7, 3]
    for review in reviewList:
        sentScore = getSentiment(reviewList[0])
        magnitude = getMagnitude(contList[idx], votList[idx])
        getOutput(reviewList[0], sentScore, magnitude)
        idx += 1

analyzeReviews()
# Out:
# Review: I thought this hotel was very nice, and reasonably priced for such an upscale atmosphere, It was incredibly clean, and all the staff were enforcing masks which I really appreciated. The hotel is in a very good location near train station and a parking garage. There is a nice bagel place steps outside the main door where you can grab coffee and a quick bite in the morning. The best thing is probably the view of Manhattan. It’s relaxing to sit on a bench and just enjoy the view of the boats and the skyline.
#
# The sentiment score is: 38.8974358974359
# The magnitude is: 5.005269705529758
#
# -------------------------------------------------------------------------------------------------------------------------
# ...
